# %%
# %load_ext autoreload
# %autoreload 2

from pathlib import Path
import sys

cwd = Path().resolve().parent.parent
if cwd not in sys.path:
    sys.path.append(str(cwd))

from src.utils.agent_models import AgentResponseModel, Message
from src.utils.submodule import Submodule
from src.utils.global_config import GlobalSettings
from src.sql_agent.api import _needs_context, sql_agent_conversation

msg = Message(role="user", content="who are top risky vendors")
conversation = AgentResponseModel()
conversation.add_message(msg)
instance = GlobalSettings.instance_by_id(GlobalSettings().active_instance_id)

sql_agent_conversation(client_id=instance.ClientUID, project_id=instance.ProjectUID, model=conversation)
# Out:
# 2025-11-17 08:57:54 +0000 - INFO - Received request for SQL agent conversation
# 2025-11-17 08:57:54 +0000 - INFO - LLM Call for: AZURE, temperature: 0.7
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2025-11-17 08:57:54 +0000 - INFO - Initializing Azure OpenAI with GPT-4o-mini model - Temperature: 0.7
# 2025-11-17 08:57:54 +0000 - INFO - Successfully initialized LLM: AZURE with temperature: 0.7
# ...
