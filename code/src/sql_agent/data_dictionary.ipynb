# %%
# %load_ext autoreload
# %autoreload 2

from pathlib import Path
import sys

root_path = Path.cwd().absolute().parent.parent
print(f"Current working directory: {root_path}")

if str(root_path) not in sys.path:
    sys.path.insert(0, str(root_path))
# Out:
# Current working directory: c:\Users\RoopakPrajapat\Documents\KonaAI_ML\code

# %%
from src.sql_agent.data_dictionary import SQLDataDictionary
from src.utils.global_config import GlobalSettings
from src.utils.instance import Instance
import pandas as pd


instance: Instance = GlobalSettings.instance_by_id(GlobalSettings().active_instance_id)

dd = SQLDataDictionary(table_schema="Analytics", table_name="Invoices", db=instance.settings.projectdb)
schema : pd.DataFrame = dd.get_schema()
display(schema)
# Out:
# 2025-11-15 17:34:56 - INFO - Table Invoices_DataDictionary does not exist. - Server=localhost, Database=GDB_DIT_Testing, Username=dofus
# 2025-11-15 17:34:56 - ERROR - Failed - Table Analytics.Invoices_DataDictionary does not exist - Server=localhost, Database=GDB_DIT_Testing, Username=dofus
# 2025-11-15 17:34:56 - WARNING - No data found in the data dictionary table Analytics.Invoices_DataDictionary. Description not updated.
# 2025-11-15 17:34:56 - INFO - Downloading data from query - Server=localhost, Database=GDB_DIT_Testing, Username=dofus - Query:
#             SELECT
#                 cols.column_name AS COLUMN_NAME,
#                 cols.data_type AS DATA_TYPE,
#                 cols.is_nullable AS IS_NULLABLE,
#                 CASE WHEN pk.column_name IS NOT NULL THEN 'YES' ELSE 'NO' END AS IS_PRIMARY_KEY,
#                 CASE WHEN uq.column_name IS NOT NULL THEN 'YES' ELSE 'NO' END AS IS_UNIQUE,
#                 -- empty description field to be filled later
# ...
