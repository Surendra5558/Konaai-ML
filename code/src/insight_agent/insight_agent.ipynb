# %%
# %load_ext autoreload
# %autoreload 2

from pathlib import Path
import os, sys

root_path = Path().parent.absolute().parent.parent
if str(root_path) not in sys.path:
    sys.path.insert(0, str(root_path))

from src.insight_agent.audit_data import AuditData
from src.utils.submodule import Submodule
from src.insight_agent.transaction_agent import TransactionAgent
import textwrap

def wrap_preserve_newlines(text, width=60):
    lines = text.split('\n')
    wrapped_lines = [textwrap.fill(line, width=width) for line in lines]
    return '\n'.join(wrapped_lines)

sub = Submodule(module='P2P', submodule='Payments', instance_id='bfee379f-02d2-478b-a7f0-bd84f08a6b0d')

ta = TransactionAgent(submodule=sub, transaction_id='865152')
report = ta.generate_summary_report()
print(wrap_preserve_newlines(report, width=100))
# Out:
# 2025-10-23 13:49:15 - INFO - LLM Call for: AZURE, temperature: 0.7
# 2025-10-23 13:49:15 - INFO - Initializing Azure OpenAI with GPT-4o-mini model - Temperature: 0.7
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2025-10-23 13:49:18 - INFO - Successfully initialized LLM: AZURE with temperature: 0.7
# 2025-10-23 13:49:19 - INFO - Table Patterns exists. - Server=localhost, Database=GDB_DIT_Testing, Username=dofus, Trusted=False
# 2025-10-23 13:49:19 - INFO - Downloading data from table - Server=localhost, Database=GDB_DIT_Testing, Username=dofus, Trusted=False - Table Name: Model.Patterns - Chunksize: 150000
# 2025-10-23 13:49:19 - INFO - Downloading chunk - Chunk: 1
# 2025-10-23 13:49:19 - INFO - Data downloaded - Server=localhost, Database=GDB_DIT_Testing, Username=dofus, Trusted=False - Rows: 220 - Columns: 102 - Size: 980.2 kB - Path: C:\Users\RoopakPrajapat\Documents\KonaAI_ML\project_data\konaai_temp\240700def1224ad6a348cdcd6a1780de
# ...
